# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
d3c = pd.read_csv("E://Anaconda//Lib//site-packages//pandas//Source_data_3.csv")
d3c.head()
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    4.4122339  4.5255726  4.6297494  4.5992994  4.8328213  4.5992994.1  \
# 0  4.2829965   4.191700   4.256104   4.113500   4.676368     4.475020
# 1  4.2515225   4.318998   4.157154   4.288386   4.262086     4.292212
# 2  4.0779844   4.140501   4.022258   4.499973   4.449097     4.387604
# 3   4.226408   4.134627   4.256750   4.287092   4.287092     4.326974
# 4  4.0264619   4.047696   4.114524   4.274912   4.253624     4.148585
#
#    4.6374562  4.8024791  4.7435732  4.4321746  ...  4.3098356  4.1186203  \
# 0   4.369442   4.271140   4.638534   4.323525  ...   3.889841   4.074805
# 1   4.318836   4.292212   4.318836   4.370143  ...   4.040959   3.830504
# 2   4.414821   4.281811   4.177149   3.977742  ...   3.920453   3.899165
# ...

# %%
import seaborn as sns

# %%
# %matplotlib inline
d3c1 = d3c.dropna()
d3c1.replace([np.inf, -np.inf], 0, inplace=True)
d3c1 = d3c1.astype("float")
plt.pcolor(d3c1)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
d1a = pd.read_csv("E://Anaconda//Lib//site-packages//pandas//fig1a.csv")
d1a.head()
# Out:
#    Energy  Intensity  Unnamed: 2  Energy.1  Intensity.1  Unnamed: 5  Energy.2  \
# 0    2.35     0.0466         NaN      2.35        0.519         NaN      2.34
# 1    2.35    -0.0213         NaN      2.35        0.508         NaN      2.33
# 2    2.35    -0.0206         NaN      2.35        0.518         NaN      2.33
# 3    2.35    -0.0147         NaN      2.34        0.512         NaN      2.33
# 4    2.35    -0.0131         NaN      2.34        0.492         NaN      2.33
#
#    Intensity.2  Unnamed: 8  Energy.3  ...  Intensity.20  Unnamed: 65  \
# 0        0.959         NaN      2.32  ...          10.5          NaN
# 1        0.987         NaN      2.32  ...          10.5          NaN
# 2        0.984         NaN      2.32  ...          10.5          NaN
# 3        0.995         NaN      2.32  ...          10.5          NaN
# 4        1.010         NaN      2.32  ...          10.5          NaN
#
#    Energy.22  Intensity.21  Unnamed: 68  Energy.23  Intensity.22  Unnamed: 71  \
# ...

# %%
x = d1a["Energy"]
y = d1a["Intensity"]
plt.scatter(x,y,c = "red", s= 3)
x1 = d1a["Energy.2"]
y1 = d1a["Intensity.2"]
plt.scatter(x1,y1,c = "orange", s= 3)
x2 = d1a["Energy.5"]
y2 = d1a["Intensity.5"]
plt.scatter(x2,y2,c = "yellow", s= 3)
x3 = d1a["Energy.8"]
y3 = d1a["Intensity.8"]
plt.scatter(x3,y3,c = "purple", s= 3)
x10 = d1a["Energy.9"]
y10 = d1a["Intensity.9"]
plt.scatter(x10,y10,c = "gold", s= 3)
x4 = d1a["Energy.11"]
y4 = d1a["Intensity.11"]
plt.scatter(x4,y4,c = "blue", s= 3)
x5 = d1a["Energy.14"]
y5 = d1a["Intensity.14"]
plt.scatter(x5,y5,c = "brown", s= 3)
x6 = d1a["Energy.17"]
y6 = d1a["Intensity.17"]
plt.scatter(x6,y6,c = "black", s= 3)
x7 = d1a["Energy.20"]
y7 = d1a["Intensity.20"]
plt.scatter(x7,y7,c = "violet", s= 3)
x8 = d1a["Energy.22"]
y8 = d1a["Intensity.22"]
plt.scatter(x8,y8,c = "grey", s= 3)
x9 = d1a["Energy.22"]
y9 = d1a["Intensity.22"]
plt.scatter(x9,y9,c = "lightcoral", s= 3)

plt.xlabel("Idler photon energy (eV)")
plt.ylabel("Intensity (normalized)")
plt.show()

# %%
d1app = pd.read_csv("E://Anaconda//Lib//site-packages//pandas//fig1app.csv")
#d1app

# %%
d1b = pd.read_csv("E://Anaconda//Lib//site-packages//pandas//fig1bMoS2_1.csv")
d1b.head()
# Out:
#    Energy Abs  Absorbance      18  Energy Idler  Power  Efficiency (x10^-10)  \
# 0        2.49      0.0539  0.9702          1.87  0.246                 0.194
# 1        2.49      0.0536  0.9648          1.89  0.443                 0.349
# 2        2.49      0.0535  0.9630          1.92  0.550                 0.433
# 3        2.49      0.0534  0.9612          1.95  0.420                 0.331
# 4        2.48      0.0532  0.9576          1.97  0.455                 0.358
#
#    Unnamed: 6  Energy Theory  Theory
# 0         NaN           2.32   0.480
# 1         NaN           2.32   0.480
# 2         NaN           2.32   0.481
# 3         NaN           2.32   0.481
# 4         NaN           2.32   0.482

# %%
x_exp = d1b["Energy Idler"]
y_exp = d1b["Power"]
plt.scatter(x_exp,y_exp,c = "purple")
x_th = d1b["Energy Theory"]
y_th = d1b["Theory"]
plt.scatter(x_th,y_th,c = "red",marker='_')
x_ab = d1b["Energy Abs"]
y_ab = d1b["18"]
plt.scatter(x_ab,y_ab,c = "grey",marker='.', s = 5)
plt.xlabel("Idler photon energy (eV)")
plt.ylabel("Power (pW)")
plt.xlim([1.8,2.4])
plt.show()

# %%
d1ca = pd.read_csv("E://Anaconda//Lib//site-packages//pandas//fig1ca.csv")
d1ca.head()
# Out:
#    Power   Counts  Power fit [µW]  Counts fit x 10^3
# 0    0.00    0.00           0.000           0.000000
# 1    5.44    1.20           0.001           0.000351
# 2    7.15    2.45           0.002           0.000703
# 3    9.15    3.19           0.003           0.001050
# 4   11.40    3.51           0.004           0.001410

# %%
x_ab = d1ca["Power "]
y_ab = d1ca["Counts"]
plt.scatter(x_ab,y_ab,c = "grey",marker='.')
plt.xlabel("Power")
plt.ylabel("Intensity")
plt.show()
